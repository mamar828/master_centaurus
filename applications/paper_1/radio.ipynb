# %%
import graphinglib as gl
from astropy.io import fits
from glob import glob


# files = glob("data/radio/*.ICLN")
# for file in files:
#     print(file)
fits.open("data/radio/CENTBIGC.ICLN")[0].header
# Out:
# SIMPLE  =                    T /
# BITPIX  =                  -32 /
# NAXIS   =                    4 /
# NAXIS1  =                 2048 /
# NAXIS2  =                 2048 /
# NAXIS3  =                    1 /
# NAXIS4  =                    1 /
# EXTEND  =                    T /Tables following main image
# BLOCKED =                    T /Tape may be blocked
# OBJECT  = 'CENTAUR '           /Source name
# TELESCOP= 'VLA     '           /
# INSTRUME= 'VLA     '           /
# OBSERVER= 'AT211   '           /
# DATE-OBS= '1998-06-18'         /Obs start date YYYY-MM-DD
# DATE-MAP= '2004-09-15'         /Last processing date YYYY-MM-DD
# BSCALE  =    1.00000000000E+00 /REAL = TAPE * BSCALE + BZERO
# BZERO   =    0.00000000000E+00 /
# BUNIT   = 'JY/BEAM '           /Units of flux
# EPOCH   =      2.000000000E+03 /Epoch of RA DEC
# VELREF  =                    3 />256 RADIO, 1 LSR 2 HEL 3 OBS
# ALTRPIX =      1.000000000E+00 /Altenate FREQ/VEL ref pixel
# ...
